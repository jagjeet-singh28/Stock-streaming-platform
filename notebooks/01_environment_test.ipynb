# %%
import sys

print(sys.version)
# Out:
# 3.9.6 (default, May 22 2026, 11:13:45)
# [Clang 21.0.0 (clang-2100.1.1.101)]

# %%
import requests
import kafka

print("Environment OK")
# Out:
# /Users/jagjeetsingh/stock-streaming-platform/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Environment OK
